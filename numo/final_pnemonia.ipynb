# %%
import os
import sys
import itertools

import numpy as np
import pandas as pd

from glob import glob
from tqdm import tqdm
from PIL import Image

import tensorflow as tf
import keras
from keras import optimizers
from keras.applications import VGG19
from tensorflow.keras.preprocessing.image import ImageDataGenerator


from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import train_test_split

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os

# Define dataset paths
ROOT_DIR = "C:/Users/Admin/Desktop/neha Bhawthankar project/chest_xray"
train_dir = os.path.join(ROOT_DIR, "train")
test_dir = os.path.join(ROOT_DIR, "test")
val_dir = os.path.join(ROOT_DIR, "val")

# Verify that the paths exist
if not os.path.isdir(train_dir):
    raise FileNotFoundError(f"Training directory not found: {train_dir}")
if not os.path.isdir(val_dir):
    raise FileNotFoundError(f"Validation directory not found: {val_dir}")

print(f"Training data directory: {train_dir}")

print(f"Test data directory: {test_dir}")
print(f"Validation data directory: {val_dir}")
# Out:
# Training data directory: C:/Users/Admin/Desktop/neha Bhawthankar project/chest_xray\train
# Test data directory: C:/Users/Admin/Desktop/neha Bhawthankar project/chest_xray\test
# Validation data directory: C:/Users/Admin/Desktop/neha Bhawthankar project/chest_xray\val

# %%
import os
import sys
import numpy as np
import pandas as pd
from glob import glob
from tqdm import tqdm
from PIL import Image

# Define image size and dataset paths
IMAGE_SIZE = (64, 64)

# Define dataset paths
ROOT_DIR = "C:/Users/Admin/Desktop/neha Bhawthankar project/chest_xray"
train_dir = os.path.join(ROOT_DIR, "train")
test_dir = os.path.join(ROOT_DIR, "test")
val_dir = os.path.join(ROOT_DIR, "val")

# Dictionary for encoding the dataset labels
classID = {'NORMAL': 0, 'PNEUMONIA': 1}

dataset = []

# Iterate over the train and validation sets
for fold_dir, fold_name in zip([train_dir,test_dir, val_dir], ['train','test' 'val']):
    print(f"\nProcessing fold: {fold_name}")

    # Iterate over classes in a set
    for class_dir in glob(os.path.join(fold_dir, '*')):
        label = os.path.basename(class_dir).upper()
        print(f"Processing class: {label}")

        # Iterate over images in a class
        for filename in tqdm(os.listdir(class_dir), file=sys.stdout):
            if filename.endswith(".jpeg"):
                # Get additional info about the type of pneumonia
                if label == 'PNEUMONIA':
                    info = filename.split("_")[1] if "_" in filename else 'unknown'
                else:
                    info = 'n.a.d.'  # No abnormalities detected

                img_file_path = os.path.join(class_dir, filename)

                # Resize and convert the image to a predefined shape and RGB color space
                image = np.array(Image.open(img_file_path).resize(IMAGE_SIZE).convert('RGB'))

                dataset.append([image, info, label, classID[label], fold_name])

# Convert to a Pandas DataFrame
cxr_df = pd.DataFrame(dataset, columns=['image', 'info', 'label', 'classID', 'fold'])  # Chest X-ray DataFrame
cxr_df = cxr_df.astype({'info': 'category', 'label': 'category', 'classID': 'uint8', 'fold': 'category'})

print(f"Dataset prepared with {len(cxr_df)} entries.")
# Out:
# Processing fold: train
# Processing class: NORMAL
# 100%|██████████| 1342/1342 [00:10<00:00, 125.19it/s]
# Processing class: PNEUMONIA
# 100%|██████████| 3876/3876 [00:11<00:00, 347.97it/s]
#
# Processing fold: testval
# Processing class: NORMAL
# 100%|██████████| 234/234 [00:01<00:00, 173.71it/s]
# Processing class: PNEUMONIA
# 100%|██████████| 390/390 [00:01<00:00, 357.99it/s]
# Dataset prepared with 5840 entries.

# %%
STORE_DATA = False

if STORE_DATA:
    cxr_df.to_pickle('cxr_df.pkl')

# %%
LOAD_DATA = True
SAVE_DATA = True

DATAFRAME_PATH = 'cxr_df.pkl'

if LOAD_DATA and os.path.exists(DATAFRAME_PATH):
    # Load the DataFrame if the file exists
    cxr_df = pd.read_pickle(DATAFRAME_PATH)
    print(f"DataFrame loaded successfully with {len(cxr_df)} entries.")
else:
    # Generate the DataFrame
    dataset = []

    # Same dataset creation code as before
    for fold_dir, fold_name in zip([train_dir,test_dir, val_dir], ['train','test' ,'val']):
        print(f"\nProcessing fold: {fold_name}")
        for class_dir in glob(os.path.join(fold_dir, '*')):
            label = os.path.basename(class_dir).upper()
            print(f"Processing class: {label}")
            for filename in tqdm(os.listdir(class_dir), file=sys.stdout):
                if filename.endswith(".jpeg"):
                    info = filename.split("_")[1] if label == 'PNEUMONIA' else 'n.a.d.'
                    img_file_path = os.path.join(class_dir, filename)
                    image = np.array(Image.open(img_file_path).resize(IMAGE_SIZE).convert('RGB'))
                    dataset.append([image, info, label, classID[label], fold_name])

    # Convert to DataFrame
    cxr_df = pd.DataFrame(dataset, columns=['image', 'info', 'label', 'classID', 'fold'])
    cxr_df = cxr_df.astype({'info': 'category', 'label': 'category', 'classID': 'uint8', 'fold': 'category'})
    print(f"DataFrame created with {len(cxr_df)} entries.")

    # Save the DataFrame if enabled
    if SAVE_DATA:
        cxr_df.to_pickle(DATAFRAME_PATH)
        print(f"DataFrame saved to {DATAFRAME_PATH}.")
# Out:
# DataFrame loaded successfully with 5856 entries.

# %%
cxr_df
# Out:
#                                                   image      info      label  \
# 0     [[[19, 19, 19], [27, 27, 27], [62, 62, 62], [7...    n.a.d.     NORMAL
# 1     [[[24, 24, 24], [36, 36, 36], [44, 44, 44], [5...    n.a.d.     NORMAL
# 2     [[[0, 0, 0], [19, 19, 19], [40, 40, 40], [59, ...    n.a.d.     NORMAL
# 3     [[[44, 44, 44], [56, 56, 56], [71, 71, 71], [8...    n.a.d.     NORMAL
# 4     [[[80, 80, 80], [65, 65, 65], [44, 44, 44], [3...    n.a.d.     NORMAL
# ...                                                 ...       ...        ...
# 5851  [[[1, 1, 1], [19, 19, 19], [31, 31, 31], [62, ...  bacteria  PNEUMONIA
# 5852  [[[0, 0, 0], [13, 13, 13], [44, 44, 44], [81, ...  bacteria  PNEUMONIA
# 5853  [[[0, 0, 0], [0, 0, 0], [0, 0, 0], [66, 66, 66...  bacteria  PNEUMONIA
# 5854  [[[59, 59, 59], [58, 58, 58], [74, 74, 74], [1...  bacteria  PNEUMONIA
# 5855  [[[0, 0, 0], [2, 2, 2], [6, 6, 6], [15, 15, 15...  bacteria  PNEUMONIA
#
#       classID   fold
# 0           0  train
# 1           0  train
# 2           0  train
# 3           0  train
# 4           0  train
# ...       ...    ...
# 5851        1    val
# 5852        1    val
# 5853        1    val
# 5854        1    val
# 5855        1    val
#
# [5856 rows x 5 columns]

# %%
cxr_df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5856 entries, 0 to 5855
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   image    5856 non-null   object
#  1   info     5856 non-null   category
#  2   label    5856 non-null   category
#  3   classID  5856 non-null   uint8
#  4   fold     5856 non-null   category
# dtypes: category(3), object(1), uint8(1)
# memory usage: 892.7 KB

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.countplot(x = cxr_df[cxr_df['fold'] == 'train']['label'])
plt.title('Train data')

plt.subplot(1,2,2)
sns.countplot(x = cxr_df[cxr_df['fold'] == 'test']['label'])
plt.title('Test data')

plt.savefig('class_distribution_sns.png')

plt.show()

# %%
plt.figure(figsize=(12,4))

plt.subplot(1,2,1)
sns.countplot(x = cxr_df[(cxr_df.fold == 'train')]['info'])
plt.title('Train data')

plt.subplot(1,2,2)
sns.countplot(x = cxr_df[(cxr_df.fold == 'test')]['info'])
plt.title('Test data')

plt.savefig('type_distribution_.png')

plt.show()

# %%
def show_batch(batch, size, hspace=0.28, wspace=0.2, title=None):
    """Show the images from the `batch`."""
    height, width = size

    plt.figure(figsize=(10,10))
    
    if title is not None:
        plt.suptitle(title, weight='bold', y=0.96)

    for n in range(height*width):
        ax = plt.subplot(height, width, n+1)
        
        plt.imshow(batch[n][0])
        plt.title(batch[n][1])
        plt.subplots_adjust(wspace=wspace, hspace=hspace)
        plt.axis("off")

# %%
# random batch from the dataset
sample_batch = cxr_df[['image', 'label']].sample(frac=1).to_numpy()

show_batch(sample_batch, size=(4, 4), hspace=0.2, wspace=0.1)
plt.savefig('sample_batch.png')

# %%
# Correct filtering using case-sensitive values
pneumonia_virus_xray = cxr_df[(cxr_df['label'] == 'PNEUMONIA') & (cxr_df['info'] == 'virus')].head(1)
pneumonia_bacteria_xray = cxr_df[(cxr_df['label'] == 'PNEUMONIA') & (cxr_df['info'] == 'bacteria')].head(1)
normal_xray = cxr_df[(cxr_df['label'] == 'NORMAL')].head(1)

# Ensure non-empty selections
if not pneumonia_virus_xray.empty:
    pneumonia_virus_xray = pneumonia_virus_xray.iloc[0][['image', 'info']]
else:
    print("No virus pneumonia images found!")
    pneumonia_virus_xray = None

if not pneumonia_bacteria_xray.empty:
    pneumonia_bacteria_xray = pneumonia_bacteria_xray.iloc[0][['image', 'info']]
else:
    print("No bacterial pneumonia images found!")
    pneumonia_bacteria_xray = None

if not normal_xray.empty:
    normal_xray = normal_xray.iloc[0][['image', 'info']]
else:
    print("No normal images found!")
    normal_xray = None

# Check if all samples are valid before visualization
sample_batch = [x for x in [pneumonia_virus_xray, pneumonia_bacteria_xray, normal_xray] if x is not None]

if sample_batch:
    show_batch(sample_batch, size=(1, len(sample_batch)), wspace=0.05)
    plt.savefig('different_types.png')
else:
    print("No images available for visualization!")
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20892\2647798280.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.imshow(batch[n][0])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20892\2647798280.py:14: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.title(batch[n][1])

# %%
print(cxr_df['label'].unique())  # Check unique values in the 'label' column
print(cxr_df['info'].unique())   # Check unique values in the 'info' column
# Out:
# ['NORMAL', 'PNEUMONIA']
# Categories (2, object): ['NORMAL', 'PNEUMONIA']
# ['n.a.d.', 'bacteria', 'virus']
# Categories (3, object): ['bacteria', 'n.a.d.', 'virus']

# %%
# input image size
IMAGE_SIZE = (64, 64, 3)

# instantiate a base model with pre-trained weights
vgg19 = VGG19(weights='imagenet',         # load weights pre-trained on ImageNet
              include_top=False,          # do not include the ImageNet classifier at the top
              input_shape=IMAGE_SIZE)  

# freeze the base model
vgg19.trainable = False

# create a new model on top
inputs = keras.Input(shape=IMAGE_SIZE)
x = vgg19(inputs, training=False)
x = keras.layers.GlobalAveragePooling2D()(x)
outputs = keras.layers.Dense(1, activation='sigmoid')(x)
model = keras.Model(inputs, outputs)

# %%
vgg19.summary()
# Out:
# Model: "vgg19"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv1 (Conv2D)           │ (None, 64, 64, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_conv2 (Conv2D)           │ (None, 64, 64, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block1_pool (MaxPooling2D)      │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv1 (Conv2D)           │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_conv2 (Conv2D)           │ (None, 32, 32, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block2_pool (MaxPooling2D)      │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv1 (Conv2D)           │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv2 (Conv2D)           │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv3 (Conv2D)           │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_conv4 (Conv2D)           │ (None, 16, 16, 256)    │       590,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block3_pool (MaxPooling2D)      │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv1 (Conv2D)           │ (None, 8, 8, 512)      │     1,180,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv2 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv3 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_conv4 (Conv2D)           │ (None, 8, 8, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block4_pool (MaxPooling2D)      │ (None, 4, 4, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv1 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv2 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv3 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_conv4 (Conv2D)           │ (None, 4, 4, 512)      │     2,359,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ block5_pool (MaxPooling2D)      │ (None, 2, 2, 512)      │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,024,384 (76.39 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 64, 64, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ vgg19 (Functional)              │ (None, 2, 2, 512)      │    20,024,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 512)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 20,024,897 (76.39 MB)
#  Trainable params: 513 (2.00 KB)
#  Non-trainable params: 20,024,384 (76.39 MB)

# %%
# split the data into train and test sets (predefined)
train_cxr_df = cxr_df[cxr_df['fold']=='train'][['image', 'classID']]
test_cxr_df = cxr_df[cxr_df['fold']=='test'][['image', 'classID']]

# split the train data into train and validation sets
train_cxr_df, val_cxr_df = train_test_split(train_cxr_df, test_size=0.2, shuffle=True)

# split the sets into examples and labels
X_train = np.stack(train_cxr_df['image'].to_numpy())
y_train = train_cxr_df['classID'].to_numpy()

X_val = np.stack(val_cxr_df['image'].to_numpy())
y_val = val_cxr_df['classID'].to_numpy()

X_test = np.stack(test_cxr_df['image'].to_numpy())
y_test = test_cxr_df['classID'].to_numpy()

# %%
pos, neg = train_cxr_df.classID.value_counts().to_numpy()

weight_for_0 = (1 / neg)*(pos+neg)/2.0 
weight_for_1 = (1 / pos)*(pos+neg)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 1.95
# Weight for class 1: 0.67

# %%
BATCH_SIZE = 32

datagen = ImageDataGenerator(rescale=1.0/255.0)

train_it = datagen.flow(X_train, 
                        y=y_train, 
                        batch_size=BATCH_SIZE, 
                        shuffle=True)

val_it = datagen.flow(X_val, 
                      y=y_val, 
                      batch_size=BATCH_SIZE, 
                      shuffle=False)

test_it = datagen.flow(X_test, 
                       y=y_test, 
                       batch_size=BATCH_SIZE, 
                       shuffle=False)

# %%
EPOCHS = 100

# configure the model for training (Adam, Binary Cross-Entropy, Accuracy)
model.compile(optimizer=keras.optimizers.Adam(learning_rate=1e-4),
              loss=keras.losses.BinaryCrossentropy(),
              metrics=[keras.metrics.BinaryAccuracy()])

# train only the trainable layers
history1 = model.fit(train_it, epochs=EPOCHS, validation_data=val_it)
# Out:
# Epoch 1/100
# c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 94ms/step - binary_accuracy: 0.7572 - loss: 0.5907 - val_binary_accuracy: 0.7395 - val_loss: 0.5652
# Epoch 2/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 92ms/step - binary_accuracy: 0.7512 - loss: 0.5461 - val_binary_accuracy: 0.7395 - val_loss: 0.5358
# Epoch 3/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 93ms/step - binary_accuracy: 0.7403 - loss: 0.5239 - val_binary_accuracy: 0.7395 - val_loss: 0.5102
# Epoch 4/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 16s 120ms/step - binary_accuracy: 0.7471 - loss: 0.4973 - val_binary_accuracy: 0.7462 - val_loss: 0.4871
# Epoch 5/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 16s 123ms/step - binary_accuracy: 0.7568 - loss: 0.4721 - val_binary_accuracy: 0.7567 - val_loss: 0.4665
# Epoch 6/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 93ms/step - binary_accuracy: 0.7603 - loss: 0.4625 - val_binary_accuracy: 0.7692 - val_loss: 0.4478
# Epoch 7/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 93ms/step - binary_accuracy: 0.7756 - loss: 0.4444 - val_binary_accuracy: 0.7874 - val_loss: 0.4310
# Epoch 8/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - binary_accuracy: 0.8052 - loss: 0.4202 - val_binary_accuracy: 0.7912 - val_loss: 0.4161
# Epoch 9/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.8046 - loss: 0.4133 - val_binary_accuracy: 0.8094 - val_loss: 0.4025
# Epoch 10/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 14s 110ms/step - binary_accuracy: 0.8259 - loss: 0.3855 - val_binary_accuracy: 0.8247 - val_loss: 0.3902
# Epoch 11/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 25s 191ms/step - binary_accuracy: 0.8332 - loss: 0.3847 - val_binary_accuracy: 0.8324 - val_loss: 0.3794
# Epoch 12/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 197ms/step - binary_accuracy: 0.8387 - loss: 0.3796 - val_binary_accuracy: 0.8420 - val_loss: 0.3692
# Epoch 13/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 195ms/step - binary_accuracy: 0.8524 - loss: 0.3550 - val_binary_accuracy: 0.8487 - val_loss: 0.3600
# Epoch 14/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 25s 194ms/step - binary_accuracy: 0.8572 - loss: 0.3451 - val_binary_accuracy: 0.8554 - val_loss: 0.3516
# Epoch 15/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 25s 187ms/step - binary_accuracy: 0.8589 - loss: 0.3457 - val_binary_accuracy: 0.8582 - val_loss: 0.3436
# Epoch 16/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 24s 186ms/step - binary_accuracy: 0.8692 - loss: 0.3283 - val_binary_accuracy: 0.8630 - val_loss: 0.3363
# Epoch 17/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 23s 177ms/step - binary_accuracy: 0.8632 - loss: 0.3263 - val_binary_accuracy: 0.8649 - val_loss: 0.3297
# Epoch 18/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 92ms/step - binary_accuracy: 0.8623 - loss: 0.3326 - val_binary_accuracy: 0.8630 - val_loss: 0.3235
# Epoch 19/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 93ms/step - binary_accuracy: 0.8673 - loss: 0.3191 - val_binary_accuracy: 0.8669 - val_loss: 0.3176
# Epoch 20/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - binary_accuracy: 0.8608 - loss: 0.3233 - val_binary_accuracy: 0.8707 - val_loss: 0.3122
# Epoch 21/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 23s 177ms/step - binary_accuracy: 0.8733 - loss: 0.3088 - val_binary_accuracy: 0.8716 - val_loss: 0.3072
# Epoch 22/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 17s 129ms/step - binary_accuracy: 0.8782 - loss: 0.3008 - val_binary_accuracy: 0.8736 - val_loss: 0.3022
# Epoch 23/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - binary_accuracy: 0.8760 - loss: 0.3058 - val_binary_accuracy: 0.8755 - val_loss: 0.2975
# Epoch 24/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 17s 133ms/step - binary_accuracy: 0.8780 - loss: 0.2917 - val_binary_accuracy: 0.8784 - val_loss: 0.2929
# Epoch 25/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 25s 187ms/step - binary_accuracy: 0.8805 - loss: 0.2945 - val_binary_accuracy: 0.8793 - val_loss: 0.2890
# Epoch 26/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 24s 185ms/step - binary_accuracy: 0.8797 - loss: 0.2918 - val_binary_accuracy: 0.8803 - val_loss: 0.2849
# Epoch 27/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 19s 142ms/step - binary_accuracy: 0.8865 - loss: 0.2838 - val_binary_accuracy: 0.8803 - val_loss: 0.2814
# Epoch 28/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - binary_accuracy: 0.8812 - loss: 0.2855 - val_binary_accuracy: 0.8803 - val_loss: 0.2778
# Epoch 29/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 95ms/step - binary_accuracy: 0.8790 - loss: 0.2814 - val_binary_accuracy: 0.8831 - val_loss: 0.2739
# Epoch 30/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.8962 - loss: 0.2634 - val_binary_accuracy: 0.8851 - val_loss: 0.2707
# Epoch 31/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - binary_accuracy: 0.8867 - loss: 0.2714 - val_binary_accuracy: 0.8822 - val_loss: 0.2680
# Epoch 32/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - binary_accuracy: 0.8897 - loss: 0.2719 - val_binary_accuracy: 0.8841 - val_loss: 0.2650
# Epoch 33/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - binary_accuracy: 0.8922 - loss: 0.2654 - val_binary_accuracy: 0.8860 - val_loss: 0.2616
# Epoch 34/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - binary_accuracy: 0.8965 - loss: 0.2560 - val_binary_accuracy: 0.8898 - val_loss: 0.2587
# Epoch 35/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.8901 - loss: 0.2686 - val_binary_accuracy: 0.8879 - val_loss: 0.2562
# Epoch 36/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.8906 - loss: 0.2599 - val_binary_accuracy: 0.8898 - val_loss: 0.2535
# Epoch 37/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9014 - loss: 0.2514 - val_binary_accuracy: 0.8937 - val_loss: 0.2508
# Epoch 38/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.8990 - loss: 0.2502 - val_binary_accuracy: 0.8937 - val_loss: 0.2482
# Epoch 39/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9002 - loss: 0.2496 - val_binary_accuracy: 0.8937 - val_loss: 0.2459
# Epoch 40/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9012 - loss: 0.2468 - val_binary_accuracy: 0.8946 - val_loss: 0.2438
# Epoch 41/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.8997 - loss: 0.2421 - val_binary_accuracy: 0.8956 - val_loss: 0.2418
# Epoch 42/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9079 - loss: 0.2359 - val_binary_accuracy: 0.8966 - val_loss: 0.2394
# Epoch 43/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.8964 - loss: 0.2420 - val_binary_accuracy: 0.8975 - val_loss: 0.2371
# Epoch 44/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9117 - loss: 0.2290 - val_binary_accuracy: 0.9013 - val_loss: 0.2348
# Epoch 45/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9102 - loss: 0.2335 - val_binary_accuracy: 0.9023 - val_loss: 0.2330
# Epoch 46/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - binary_accuracy: 0.9100 - loss: 0.2237 - val_binary_accuracy: 0.8994 - val_loss: 0.2315
# Epoch 47/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 101ms/step - binary_accuracy: 0.9121 - loss: 0.2285 - val_binary_accuracy: 0.9023 - val_loss: 0.2294
# Epoch 48/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - binary_accuracy: 0.9185 - loss: 0.2256 - val_binary_accuracy: 0.9042 - val_loss: 0.2275
# Epoch 49/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - binary_accuracy: 0.9186 - loss: 0.2174 - val_binary_accuracy: 0.9061 - val_loss: 0.2258
# Epoch 50/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - binary_accuracy: 0.9091 - loss: 0.2336 - val_binary_accuracy: 0.9052 - val_loss: 0.2245
# Epoch 51/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - binary_accuracy: 0.9199 - loss: 0.2148 - val_binary_accuracy: 0.9080 - val_loss: 0.2222
# Epoch 52/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - binary_accuracy: 0.9165 - loss: 0.2234 - val_binary_accuracy: 0.9061 - val_loss: 0.2210
# Epoch 53/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - binary_accuracy: 0.9136 - loss: 0.2259 - val_binary_accuracy: 0.9061 - val_loss: 0.2197
# Epoch 54/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - binary_accuracy: 0.9170 - loss: 0.2198 - val_binary_accuracy: 0.9090 - val_loss: 0.2178
# Epoch 55/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - binary_accuracy: 0.9213 - loss: 0.2112 - val_binary_accuracy: 0.9138 - val_loss: 0.2161
# Epoch 56/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - binary_accuracy: 0.9164 - loss: 0.2184 - val_binary_accuracy: 0.9100 - val_loss: 0.2150
# Epoch 57/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - binary_accuracy: 0.9125 - loss: 0.2142 - val_binary_accuracy: 0.9100 - val_loss: 0.2138
# Epoch 58/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9228 - loss: 0.2122 - val_binary_accuracy: 0.9157 - val_loss: 0.2121
# Epoch 59/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9235 - loss: 0.2052 - val_binary_accuracy: 0.9138 - val_loss: 0.2111
# Epoch 60/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9190 - loss: 0.2100 - val_binary_accuracy: 0.9176 - val_loss: 0.2093
# Epoch 61/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9220 - loss: 0.2073 - val_binary_accuracy: 0.9176 - val_loss: 0.2081
# Epoch 62/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9307 - loss: 0.2023 - val_binary_accuracy: 0.9186 - val_loss: 0.2071
# Epoch 63/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9195 - loss: 0.2078 - val_binary_accuracy: 0.9186 - val_loss: 0.2059
# Epoch 64/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9228 - loss: 0.2041 - val_binary_accuracy: 0.9195 - val_loss: 0.2048
# Epoch 65/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9161 - loss: 0.2051 - val_binary_accuracy: 0.9215 - val_loss: 0.2034
# Epoch 66/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9256 - loss: 0.2019 - val_binary_accuracy: 0.9234 - val_loss: 0.2022
# Epoch 67/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9214 - loss: 0.2071 - val_binary_accuracy: 0.9224 - val_loss: 0.2013
# Epoch 68/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - binary_accuracy: 0.9282 - loss: 0.1976 - val_binary_accuracy: 0.9243 - val_loss: 0.2001
# Epoch 69/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - binary_accuracy: 0.9261 - loss: 0.1994 - val_binary_accuracy: 0.9243 - val_loss: 0.1993
# Epoch 70/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9265 - loss: 0.1978 - val_binary_accuracy: 0.9253 - val_loss: 0.1983
# Epoch 71/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 14s 103ms/step - binary_accuracy: 0.9278 - loss: 0.1966 - val_binary_accuracy: 0.9253 - val_loss: 0.1974
# Epoch 72/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 24s 187ms/step - binary_accuracy: 0.9257 - loss: 0.1884 - val_binary_accuracy: 0.9262 - val_loss: 0.1965
# Epoch 73/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 149ms/step - binary_accuracy: 0.9285 - loss: 0.1847 - val_binary_accuracy: 0.9272 - val_loss: 0.1951
# Epoch 74/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - binary_accuracy: 0.9259 - loss: 0.2013 - val_binary_accuracy: 0.9291 - val_loss: 0.1943
# Epoch 75/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9282 - loss: 0.1889 - val_binary_accuracy: 0.9291 - val_loss: 0.1933
# Epoch 76/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - binary_accuracy: 0.9316 - loss: 0.1872 - val_binary_accuracy: 0.9310 - val_loss: 0.1923
# Epoch 77/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 16s 126ms/step - binary_accuracy: 0.9315 - loss: 0.1895 - val_binary_accuracy: 0.9310 - val_loss: 0.1918
# Epoch 78/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 26s 198ms/step - binary_accuracy: 0.9278 - loss: 0.1950 - val_binary_accuracy: 0.9339 - val_loss: 0.1908
# Epoch 79/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 18s 134ms/step - binary_accuracy: 0.9284 - loss: 0.1928 - val_binary_accuracy: 0.9330 - val_loss: 0.1902
# Epoch 80/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 15s 112ms/step - binary_accuracy: 0.9354 - loss: 0.1869 - val_binary_accuracy: 0.9330 - val_loss: 0.1894
# Epoch 81/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - binary_accuracy: 0.9289 - loss: 0.1915 - val_binary_accuracy: 0.9330 - val_loss: 0.1886
# Epoch 82/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 98ms/step - binary_accuracy: 0.9346 - loss: 0.1843 - val_binary_accuracy: 0.9349 - val_loss: 0.1877
# Epoch 83/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - binary_accuracy: 0.9362 - loss: 0.1831 - val_binary_accuracy: 0.9349 - val_loss: 0.1869
# Epoch 84/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 101ms/step - binary_accuracy: 0.9376 - loss: 0.1825 - val_binary_accuracy: 0.9349 - val_loss: 0.1863
# Epoch 85/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 23s 177ms/step - binary_accuracy: 0.9411 - loss: 0.1749 - val_binary_accuracy: 0.9349 - val_loss: 0.1854
# Epoch 86/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 25s 192ms/step - binary_accuracy: 0.9352 - loss: 0.1815 - val_binary_accuracy: 0.9358 - val_loss: 0.1847
# Epoch 87/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 19s 147ms/step - binary_accuracy: 0.9294 - loss: 0.1893 - val_binary_accuracy: 0.9358 - val_loss: 0.1841
# Epoch 88/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 18s 138ms/step - binary_accuracy: 0.9330 - loss: 0.1846 - val_binary_accuracy: 0.9368 - val_loss: 0.1835
# Epoch 89/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - binary_accuracy: 0.9395 - loss: 0.1846 - val_binary_accuracy: 0.9358 - val_loss: 0.1825
# Epoch 90/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - binary_accuracy: 0.9430 - loss: 0.1722 - val_binary_accuracy: 0.9368 - val_loss: 0.1820
# Epoch 91/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - binary_accuracy: 0.9419 - loss: 0.1720 - val_binary_accuracy: 0.9368 - val_loss: 0.1811
# Epoch 92/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 18s 134ms/step - binary_accuracy: 0.9440 - loss: 0.1767 - val_binary_accuracy: 0.9368 - val_loss: 0.1808
# Epoch 93/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 25s 193ms/step - binary_accuracy: 0.9353 - loss: 0.1797 - val_binary_accuracy: 0.9368 - val_loss: 0.1801
# Epoch 94/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 23s 175ms/step - binary_accuracy: 0.9331 - loss: 0.1882 - val_binary_accuracy: 0.9358 - val_loss: 0.1798
# Epoch 95/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 12s 94ms/step - binary_accuracy: 0.9348 - loss: 0.1785 - val_binary_accuracy: 0.9377 - val_loss: 0.1788
# Epoch 96/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 16s 120ms/step - binary_accuracy: 0.9412 - loss: 0.1752 - val_binary_accuracy: 0.9406 - val_loss: 0.1780
# Epoch 97/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 20s 156ms/step - binary_accuracy: 0.9379 - loss: 0.1805 - val_binary_accuracy: 0.9377 - val_loss: 0.1776
# Epoch 98/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 96ms/step - binary_accuracy: 0.9427 - loss: 0.1710 - val_binary_accuracy: 0.9387 - val_loss: 0.1770
# Epoch 99/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - binary_accuracy: 0.9395 - loss: 0.1770 - val_binary_accuracy: 0.9377 - val_loss: 0.1767
# Epoch 100/100
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - binary_accuracy: 0.9413 - loss: 0.1698 - val_binary_accuracy: 0.9387 - val_loss: 0.1760

# %%
model.evaluate(test_it, return_dict=True)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 74ms/step - binary_accuracy: 0.5844 - loss: 0.8704
# {'binary_accuracy': 0.7628205418586731, 'loss': 0.5020226836204529}

# %%
EPOCHS_FT = 1

# unfreeze the base model
vgg19.trainable = True

# recompile the model with a smaller learning rate value
model.compile(optimizer=keras.optimizers.Adam(1e-5),  
              loss=keras.losses.BinaryCrossentropy(),
              metrics=[keras.metrics.BinaryAccuracy()])

# train end-to-end
history2 = model.fit(train_it, epochs=EPOCHS_FT, batch_size=BATCH_SIZE, validation_data=val_it)
# Out:
# 131/131 ━━━━━━━━━━━━━━━━━━━━ 36s 250ms/step - binary_accuracy: 0.9321 - loss: 0.1641 - val_binary_accuracy: 0.9761 - val_loss: 0.0718

# %%
model.evaluate(test_it, return_dict=True)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - binary_accuracy: 0.6527 - loss: 1.2286
# {'binary_accuracy': 0.7996794581413269, 'loss': 0.6947094202041626}

# %%
def show_history(history, figsize=(15,5), save_fig=True, print_results=True):
    """Shows accuracy and loss graphs for train and validation sets."""    
    
    df = pd.DataFrame(history)

    sns.set()
    plt.figure(figsize=figsize)

    # accuracy graph
    plt.subplot(1,2,1)
    g = sns.lineplot(data=df[['binary_accuracy', 'val_binary_accuracy']], dashes=False)
    g.set(title='Model Accuracy', xlabel='Epoch', ylabel='Accuracy')
    g.legend(labels=['train', 'validation'])

    # loss graph
    plt.subplot(1,2,2)
    g = sns.lineplot(data=df[['loss', 'val_loss']], dashes=False)
    g.set(title='Model loss', xlabel='Epoch', ylabel='Loss')
    g.legend(labels=['train', 'validation'])

    plt.subplots_adjust(wspace=0.23)
    
    if save_fig:
        plt.savefig('acc_loss_graphs.png')

    plt.show()

    if print_results:
        print('\n\tMax train accuracy: %.4f %%\033[0m\t\t\t\tMin train loss: %.5f' % (df.binary_accuracy.max() * 100,
                                                                                      df.loss.min()))
        print('\tMax validation accuracy: %.4f %%\t\t\tMin validation loss: %.5f' % (df.val_binary_accuracy.max() * 100, 
                                                                                     df.val_loss.min()))

# %%
history1.history['binary_accuracy'] += history2.history['binary_accuracy']
history1.history['val_binary_accuracy'] += history2.history['val_binary_accuracy']
history1.history['loss'] += history2.history['loss']
history1.history['val_loss'] += history2.history['val_loss']

show_history(history1.history)
# Out:
# 	Max train accuracy: 95.2541 %				Min train loss: 0.12022
# 	Max validation accuracy: 97.6054 %			Min validation loss: 0.07180

# %%
labels =  ['normal', 'pneumonia']

y_true = y_test
y_pred = tf.round(model.predict(x=test_it, batch_size=BATCH_SIZE)).numpy().T[0]
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step

# %%
cm = confusion_matrix(y_true=y_test, y_pred=y_pred) 
cm_normalized = confusion_matrix(y_true=y_test, y_pred=y_pred, normalize='true') 

# plot matrices and save the fig
plt.figure(figsize=(15,6))

for i, cmx in enumerate([cm_normalized, cm]):
    plt.subplot(1,2,i+1)
    cmx_df = pd.DataFrame(cmx, columns=labels, index=labels).round(2)
    g = sns.heatmap(cmx_df, annot=True, fmt='g', cmap='Blues')
    g.set(title='Confusion Matrix', xlabel='Predicted label', ylabel='True label')

plt.subplots_adjust(wspace=0.25)
plt.savefig('confusion_matrices.png')
plt.show()

# %%
report = classification_report(y_true, y_pred, target_names=['normal', 'pneumonia'], output_dict=True)
report = pd.DataFrame(report).iloc[:-1, :].T

# plot the classificaton report
plt.figure(figsize=(10,8))
sns.heatmap(report, annot=True, cmap='YlOrRd')
plt.yticks(va='center')
plt.savefig('classifcation_report.png')
plt.show()

# %%
def plot_top_losses(top_k, X, y_true, predict, loss, labels, **kwargs):
    """Shows the examples with the highest loss in the dataset."""
    
    y_pred = predict(x=X, batch_size=BATCH_SIZE)
    loss_values = np.array(loss(y_true, y_pred))
    top_k_idxs = loss_values.argsort()[-top_k:][::-1]

    worst_batch = []
    for idx in top_k_idxs:
        true_prob = y_test[idx]*y_pred[idx] + (1-y_test[idx])*(1-y_pred[idx])
        classID = int(y_true[idx])
        title = '%s / %.3f / %.4f' % (labels[classID], loss_values[idx], true_prob)
        worst_batch.append((X[idx], title))

    show_batch(worst_batch, title='Actual/Loss/Prediction_Probability', **kwargs)

# %%
loss_f = keras.losses.BinaryCrossentropy(reduction=tf.keras.losses.Reduction.NONE)

plot_top_losses(top_k=9,
                X=X_test/255.0, 
                y_true=y_test.reshape(-1, 1),               
                predict=model.predict, 
                loss=loss_f, 
                labels=labels,
                size=(3,3))

plt.savefig('top_losses.png', dpi=350)
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20892\422491696.py:11: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   classID = int(y_true[idx])
# C:\Users\Admin\AppData\Local\Temp\ipykernel_20892\422491696.py:12: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   title = '%s / %.3f / %.4f' % (labels[classID], loss_values[idx], true_prob)

# %%
# Save the model to an .h5 file
model_save_path = '100epoch.h5'
model.save(model_save_path)
print(f"Model saved to {model_save_path}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to 100epoch.h5

# %%
from tensorflow.keras.models import load_model
import numpy as np
from tensorflow.keras.preprocessing.image import load_img, img_to_array

# Load the model
model_path = '100epoch.h5'
model = load_model(model_path)
print("Model loaded successfully!")
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# Model loaded successfully!

# %%
# Path to a sample image
image_path = 'person16_virus_47.jpeg'  # Replace with your test image path

# Load and preprocess the image
image_size = (64, 64)  # Ensure this matches your model's input size
image = load_img(image_path, target_size=image_size)  # Load and resize the image
image_array = img_to_array(image) / 255.0            # Convert to array and normalize
image_array = np.expand_dims(image_array, axis=0)    # Add batch dimension

print(f"Prepared image shape: {image_array.shape}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[34], line 6
#       4 # Load and preprocess the image
#       5 image_size = (64, 64)  # Ensure this matches your model's input size
# ----> 6 image = load_img(image_path, target_size=image_size)  # Load and resize the image
#       7 image_array = img_to_array(image) / 255.0            # Convert to array and normalize
#       8 image_array = np.expand_dims(image_array, axis=0)    # Add batch dimension
#
# File c:\Users\Admin\anaconda3\Lib\site-packages\keras\src\utils\image_utils.py:235, in load_img(path, color_mode, target_size, interpolation, keep_aspect_ratio)
#     233     if isinstance(path, pathlib.Path):
#     234         path = str(path.resolve())
# --> 235     with open(path, "rb") as f:
#     236         img = pil_image.open(io.BytesIO(f.read()))
#     237 else:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'person16_virus_47.jpeg'

# %%
# Path to a sample image
image_path = 'person16_virus_47.jpeg'  # Replace with your test image path

# Load and preprocess the image
image_size = (64, 64)  # Ensure this matches your model's input size
image = load_img(image_path, target_size=image_size)  # Load and resize the image
image_array = img_to_array(image) / 255.0            # Convert to array and normalize
image_array = np.expand_dims(image_array, axis=0)    # Add batch dimension

print(f"Prepared image shape: {image_array.shape}")

# %%
# Make a prediction
# Make a prediction
predicted_prob = model.predict(image_array)[0][0]  # Model prediction
predicted_class = 'Pneumonia' if predicted_prob >= 0.4 else 'Normal'

print(f"Predicted Probability: {predicted_prob:.2f}")
print(f"Predicted Class: {predicted_class}")
